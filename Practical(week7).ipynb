# %%
import cv2 as cv
import numpy as py
import pytesseract 

pytesseract.pytesseract.tesseract_cmd = r'C:\Users\admin\Downloads\tesseract-3.02.02-win32-lib-include-dirs.zip\tesseract-3.02.02-win32-lib-include-dirs\include\tesseract'

img = cv.imread(r"C:\Users\admin\Downloads\book.jpeg")
print(img.shape)
img2 = img.copy()
# -- Vanilla OCR
print(pytesseract.image_to_string(img))

# -- Vanilla OCR + image processing
# median filtering set as 5 = a 5 x 5 kernal (kernal size always odd number)
# img2 = cv.medianBlur(img2, 5)
img2 = cv.resize(img2,None,fx=2,fy=2,interpolation = cv.INTER_CUBIC)
print(pytesseract.image_to_string(img2))

# -- Vanilla OCR + image processing + Lang
print(pytesseract.image_to_string(img2, lang='msa'))

# -- Vanilla OCR + image processing + Lang + ROI
print(pytesseract.image_to_string("What you want?", img2))
copped_image = img2[int(r[1]):int(r[1]+r[3]),
    int(r[0]):int(r[0]+r[2])]
ret,thresh1 = cv.threshold(copped_image,40,255,cv.THREH_BINARY)

print(pytessereact.image_to_string(thresh1, lang='msa+eng'))

cv.imshow("Ori", img)
cv.imshow("Ori after median", img2)
cv.imshow("Crop", cropped_image)
cv.imshow("Thresholding", thresh1)
cv.waitKey()
# Out:
# (276, 201, 3)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File C:\ProgramData\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...
